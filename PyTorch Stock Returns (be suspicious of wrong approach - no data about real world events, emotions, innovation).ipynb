# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Part 1: Price Prediction

# %%
# yes, you can read dataframes from URLs!
df = pd.read_csv('https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/sbux.csv')

# %%
df.head()
# Out:
#          date    open    high     low   close   volume  Name
# 0  2013-02-08  27.920  28.325  27.920  28.185  7146296  SBUX
# 1  2013-02-11  28.260  28.260  27.930  28.070  5457354  SBUX
# 2  2013-02-12  28.000  28.275  27.975  28.130  8665592  SBUX
# 3  2013-02-13  28.230  28.230  27.750  27.915  7022056  SBUX
# 4  2013-02-14  27.765  27.905  27.675  27.775  8899188  SBUX

# %%
df.tail()
# Out:
#             date    open   high    low  close    volume  Name
# 1254  2018-02-01  56.280  56.42  55.89  56.00  14690146  SBUX
# 1255  2018-02-02  55.900  56.32  55.70  55.77  15358909  SBUX
# 1256  2018-02-05  55.530  56.26  54.57  54.69  16059955  SBUX
# 1257  2018-02-06  53.685  56.06  53.56  55.61  17415065  SBUX
# 1258  2018-02-07  55.080  55.43  54.44  54.46  13927022  SBUX

# %%
# Start by doing the WRONG thing - trying to predict the price itself
series = df['close'].values.reshape(-1, 1)

# %%
# Normalize the data
# Note: I didn't think about where the true boundary is, this is just approx.
scaler = StandardScaler()

# Fit only on train data
scaler.fit(series[:len(series) // 2])

# But transform all data
series = scaler.transform(series).flatten()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 20
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y).reshape(-1, 1)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (1239, 20, 1) Y.shape (1239, 1)

# %%
### try autoregressive RNN model
class RNN(nn.Module):
  def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
    super(RNN, self).__init__()
    self.D = n_inputs
    self.M = n_hidden
    self.K = n_outputs
    self.L = n_rnnlayers

    self.rnn = nn.LSTM(
        input_size=self.D,
        hidden_size=self.M,
        num_layers=self.L,
        batch_first=True)
    self.fc = nn.Linear(self.M, self.K)
  
  def forward(self, X):
    # initial hidden states
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
    c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    # get RNN unit output
    out, _ = self.rnn(X, (h0, c0))

    # we only want h(T) at the final time step
    out = self.fc(out[:, -1, :])
    return out

# %%
model = RNN(1, 5, 1, 1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)
# Out:
# cpu
# RNN(
#   (rnn): LSTM(1, 5, batch_first=True)
#   (fc): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
# Training
def full_gd(model,
            criterion,
            optimizer,
            X_train,
            y_train,
            X_test,
            y_test,
            epochs=200):

  # Stuff to store
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    # zero the parameter gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
      
    # Backward and optimize
    loss.backward()
    optimizer.step()

    # Save losses
    train_losses[it] = loss.item()

    # Test loss
    test_outputs = model(X_test)
    test_loss = criterion(test_outputs, y_test)
    test_losses[it] = test_loss.item()
      
    if (it + 1) % 5 == 0:
      print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')
  
  return train_losses, test_losses

# %%
# Make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test)
# Out:
# Epoch 5/200, Train Loss: 0.2077, Test Loss: 0.2339
# Epoch 10/200, Train Loss: 0.0834, Test Loss: 0.0640
# Epoch 15/200, Train Loss: 0.0242, Test Loss: 0.0373
# Epoch 20/200, Train Loss: 0.0197, Test Loss: 0.0158
# Epoch 25/200, Train Loss: 0.0147, Test Loss: 0.0156
# Epoch 30/200, Train Loss: 0.0123, Test Loss: 0.0425
# Epoch 35/200, Train Loss: 0.0097, Test Loss: 0.0154
# Epoch 40/200, Train Loss: 0.0084, Test Loss: 0.0201
# Epoch 45/200, Train Loss: 0.0074, Test Loss: 0.0172
# Epoch 50/200, Train Loss: 0.0065, Test Loss: 0.0196
# Epoch 55/200, Train Loss: 0.0061, Test Loss: 0.0164
# Epoch 60/200, Train Loss: 0.0058, Test Loss: 0.0188
# Epoch 65/200, Train Loss: 0.0056, Test Loss: 0.0193
# Epoch 70/200, Train Loss: 0.0056, Test Loss: 0.0153
# Epoch 75/200, Train Loss: 0.0055, Test Loss: 0.0159
# Epoch 80/200, Train Loss: 0.0055, Test Loss: 0.0142
# Epoch 85/200, Train Loss: 0.0054, Test Loss: 0.0140
# Epoch 90/200, Train Loss: 0.0054, Test Loss: 0.0143
# Epoch 95/200, Train Loss: 0.0053, Test Loss: 0.0133
# Epoch 100/200, Train Loss: 0.0053, Test Loss: 0.0129
# Epoch 105/200, Train Loss: 0.0053, Test Loss: 0.0129
# Epoch 110/200, Train Loss: 0.0052, Test Loss: 0.0128
# Epoch 115/200, Train Loss: 0.0052, Test Loss: 0.0126
# Epoch 120/200, Train Loss: 0.0052, Test Loss: 0.0125
# Epoch 125/200, Train Loss: 0.0052, Test Loss: 0.0125
# Epoch 130/200, Train Loss: 0.0052, Test Loss: 0.0124
# Epoch 135/200, Train Loss: 0.0052, Test Loss: 0.0123
# Epoch 140/200, Train Loss: 0.0052, Test Loss: 0.0123
# Epoch 145/200, Train Loss: 0.0052, Test Loss: 0.0122
# Epoch 150/200, Train Loss: 0.0052, Test Loss: 0.0122
# Epoch 155/200, Train Loss: 0.0051, Test Loss: 0.0122
# Epoch 160/200, Train Loss: 0.0051, Test Loss: 0.0122
# Epoch 165/200, Train Loss: 0.0051, Test Loss: 0.0122
# Epoch 170/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 175/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 180/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 185/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 190/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 195/200, Train Loss: 0.0051, Test Loss: 0.0121
# Epoch 200/200, Train Loss: 0.0051, Test Loss: 0.0121

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# One-step forecast using true targets
validation_target = Y
validation_predictions = []

# index of first validation input
i = 0

X_on_device = torch.from_numpy(X.astype(np.float32)).to(device)

while len(validation_predictions) < len(validation_target):
  input_ = X_on_device[i].reshape(1, T, 1)
  p = model(input_)[0,0].item() # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Multi-step forecast
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X_test[0].view(T)

while len(validation_predictions) < len(validation_target):
  input_ = last_x.reshape(1, T, 1)
  p = model(input_)
  # [0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p[0,0].item())
  
  # make the new input
  last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %% [markdown]
# # Part 2: Returns

# %%
# calculate returns by first shifting the data
df['PrevClose'] = df['close'].shift(1) # move everything up 1

# so now it's like
# close / prev close
# x[2] x[1]
# x[3] x[2]
# x[4] x[3]
# ...
# x[t] x[t-1]

# %%
df.head()
# Out:
#          date    open    high     low   close   volume  Name  PrevClose
# 0  2013-02-08  27.920  28.325  27.920  28.185  7146296  SBUX        NaN
# 1  2013-02-11  28.260  28.260  27.930  28.070  5457354  SBUX     28.185
# 2  2013-02-12  28.000  28.275  27.975  28.130  8665592  SBUX     28.070
# 3  2013-02-13  28.230  28.230  27.750  27.915  7022056  SBUX     28.130
# 4  2013-02-14  27.765  27.905  27.675  27.775  8899188  SBUX     27.915

# %%
# then the return is
# (x[t] - x[t-1]) / x[t-1]
df['Return'] = (df['close'] - df['PrevClose']) / df['PrevClose']

# %%
df.head()
# Out:
#          date    open    high     low   close   volume  Name  PrevClose  \
# 0  2013-02-08  27.920  28.325  27.920  28.185  7146296  SBUX        NaN
# 1  2013-02-11  28.260  28.260  27.930  28.070  5457354  SBUX     28.185
# 2  2013-02-12  28.000  28.275  27.975  28.130  8665592  SBUX     28.070
# 3  2013-02-13  28.230  28.230  27.750  27.915  7022056  SBUX     28.130
# 4  2013-02-14  27.765  27.905  27.675  27.775  8899188  SBUX     27.915
#
#      Return
# 0       NaN
# 1 -0.004080
# 2  0.002138
# 3 -0.007643
# 4 -0.005015

# %%
plt.plot(df['Return']);

# %%
# Now let's try an LSTM to predict returns
df['Return'].hist()
# Out:
# <Axes: >

# %%
# Exclude the first NaN value
series = df['Return'].values[1:].reshape(-1, 1)

# Normalize the data
# Note: I didn't think about where the true boundary is, this is just approx.
scaler = StandardScaler()
scaler.fit(series[:len(series) // 2])
series = scaler.transform(series).flatten()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 20
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y).reshape(-1, 1)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (1238, 20, 1) Y.shape (1238, 1)

# %%
### try autoregressive RNN model
model = RNN(1, 5, 1, 1)
model.to(device)
# Out:
# RNN(
#   (rnn): LSTM(1, 5, batch_first=True)
#   (fc): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test)
# Out:
# Epoch 5/200, Train Loss: 1.1407, Test Loss: 1.1743
# Epoch 10/200, Train Loss: 1.0758, Test Loss: 1.1006
# Epoch 15/200, Train Loss: 1.0530, Test Loss: 1.0687
# Epoch 20/200, Train Loss: 1.0585, Test Loss: 1.0661
# Epoch 25/200, Train Loss: 1.0564, Test Loss: 1.0663
# Epoch 30/200, Train Loss: 1.0501, Test Loss: 1.0698
# Epoch 35/200, Train Loss: 1.0486, Test Loss: 1.0755
# Epoch 40/200, Train Loss: 1.0484, Test Loss: 1.0780
# Epoch 45/200, Train Loss: 1.0468, Test Loss: 1.0767
# Epoch 50/200, Train Loss: 1.0448, Test Loss: 1.0743
# Epoch 55/200, Train Loss: 1.0433, Test Loss: 1.0734
# Epoch 60/200, Train Loss: 1.0418, Test Loss: 1.0749
# Epoch 65/200, Train Loss: 1.0400, Test Loss: 1.0783
# Epoch 70/200, Train Loss: 1.0382, Test Loss: 1.0824
# Epoch 75/200, Train Loss: 1.0364, Test Loss: 1.0852
# Epoch 80/200, Train Loss: 1.0343, Test Loss: 1.0873
# Epoch 85/200, Train Loss: 1.0321, Test Loss: 1.0905
# Epoch 90/200, Train Loss: 1.0294, Test Loss: 1.0950
# Epoch 95/200, Train Loss: 1.0263, Test Loss: 1.0988
# Epoch 100/200, Train Loss: 1.0227, Test Loss: 1.1022
# Epoch 105/200, Train Loss: 1.0183, Test Loss: 1.1078
# Epoch 110/200, Train Loss: 1.0129, Test Loss: 1.1130
# Epoch 115/200, Train Loss: 1.0057, Test Loss: 1.1226
# Epoch 120/200, Train Loss: 0.9956, Test Loss: 1.1457
# Epoch 125/200, Train Loss: 0.9897, Test Loss: 1.1791
# Epoch 130/200, Train Loss: 0.9863, Test Loss: 1.1789
# Epoch 135/200, Train Loss: 0.9802, Test Loss: 1.1746
# Epoch 140/200, Train Loss: 0.9756, Test Loss: 1.1812
# Epoch 145/200, Train Loss: 0.9699, Test Loss: 1.1926
# Epoch 150/200, Train Loss: 0.9635, Test Loss: 1.2060
# Epoch 155/200, Train Loss: 0.9568, Test Loss: 1.2136
# Epoch 160/200, Train Loss: 0.9498, Test Loss: 1.2516
# Epoch 165/200, Train Loss: 0.9444, Test Loss: 1.2723
# Epoch 170/200, Train Loss: 0.9397, Test Loss: 1.2728
# Epoch 175/200, Train Loss: 0.9336, Test Loss: 1.2803
# Epoch 180/200, Train Loss: 0.9326, Test Loss: 1.2940
# Epoch 185/200, Train Loss: 0.9252, Test Loss: 1.3003
# Epoch 190/200, Train Loss: 0.9209, Test Loss: 1.3153
# Epoch 195/200, Train Loss: 0.9173, Test Loss: 1.3138
# Epoch 200/200, Train Loss: 0.9177, Test Loss: 1.3678

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# One-step forecast using true targets
validation_target = Y
validation_predictions = []

# index of first validation input
i = 0

X_on_device = torch.from_numpy(X.astype(np.float32)).to(device)

while len(validation_predictions) < len(validation_target):
  input_ = X_on_device[i].reshape(1, T, 1)
  p = model(input_)[0,0].item() # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Multi-step forecast
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X_test[0].view(T)

while len(validation_predictions) < len(validation_target):
  input_ = last_x.reshape(1, T, 1)
  p = model(input_)
  # [0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p[0,0].item())
  
  # make the new input
  last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %% [markdown]
# # Part 3: Binary Classification

# %%
# Now turn the full data into numpy arrays

# Not yet in the final "X" format!
input_data = df[['open', 'high', 'low', 'close', 'volume']].values
targets = df['Return'].values

# %%
# Now make the actual data which will go into the neural network
T = 10 # the number of time steps to look at to make a prediction for the next day
D = input_data.shape[1]
N = len(input_data) - T # (e.g. if T=10 and you have 11 data points then you'd only have 1 sample)

# %%
# normalize the inputs
Ntrain = len(input_data) * 2 // 3
scaler = StandardScaler()
scaler.fit(input_data[:Ntrain + T - 1])
input_data = scaler.transform(input_data)

# %%
# Setup X_train and Y_train
X_train = np.zeros((Ntrain, T, D))
Y_train = np.zeros((Ntrain, 1))

for t in range(Ntrain):
  X_train[t, :, :] = input_data[t:t+T]
  Y_train[t] = (targets[t+T] > 0)

# %%
# Setup X_test and Y_test
X_test = np.zeros((N - Ntrain, T, D))
Y_test = np.zeros((N - Ntrain, 1))

for u in range(N - Ntrain):
  # u counts from 0...(N - Ntrain)
  # t counts from Ntrain...N
  t = u + Ntrain
  X_test[u, :, :] = input_data[t:t+T]
  Y_test[u] = (targets[t+T] > 0)

# %%
# make the RNN
model = RNN(5, 50, 2, 1)
model.to(device)
# Out:
# RNN(
#   (rnn): LSTM(5, 50, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
# Loss and optimizer - it's classification now!
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X_train.astype(np.float32))
y_train = torch.from_numpy(Y_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))
y_test = torch.from_numpy(Y_test.astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test,
                                    epochs=300)
# Out:
# Epoch 5/300, Train Loss: 0.6920, Test Loss: 0.6937
# Epoch 10/300, Train Loss: 0.6909, Test Loss: 0.6935
# Epoch 15/300, Train Loss: 0.6882, Test Loss: 0.6914
# Epoch 20/300, Train Loss: 0.6848, Test Loss: 0.6989
# Epoch 25/300, Train Loss: 0.6808, Test Loss: 0.7120
# Epoch 30/300, Train Loss: 0.6776, Test Loss: 0.7181
# Epoch 35/300, Train Loss: 0.6707, Test Loss: 0.7269
# Epoch 40/300, Train Loss: 0.6627, Test Loss: 0.7816
# Epoch 45/300, Train Loss: 0.6549, Test Loss: 0.7684
# Epoch 50/300, Train Loss: 0.6422, Test Loss: 0.7927
# Epoch 55/300, Train Loss: 0.6213, Test Loss: 0.8682
# Epoch 60/300, Train Loss: 0.5998, Test Loss: 0.8742
# Epoch 65/300, Train Loss: 0.5804, Test Loss: 0.9204
# Epoch 70/300, Train Loss: 0.5549, Test Loss: 0.9858
# Epoch 75/300, Train Loss: 0.5269, Test Loss: 1.0242
# Epoch 80/300, Train Loss: 0.5242, Test Loss: 1.1248
# Epoch 85/300, Train Loss: 0.4927, Test Loss: 1.1587
# Epoch 90/300, Train Loss: 0.4593, Test Loss: 1.1319
# Epoch 95/300, Train Loss: 0.4290, Test Loss: 1.3131
# Epoch 100/300, Train Loss: 0.3973, Test Loss: 1.3861
# Epoch 105/300, Train Loss: 0.3675, Test Loss: 1.5727
# Epoch 110/300, Train Loss: 0.3872, Test Loss: 1.7171
# Epoch 115/300, Train Loss: 0.3377, Test Loss: 1.6711
# Epoch 120/300, Train Loss: 0.3111, Test Loss: 1.8184
# Epoch 125/300, Train Loss: 0.2821, Test Loss: 1.8951
# Epoch 130/300, Train Loss: 0.2595, Test Loss: 2.0205
# Epoch 135/300, Train Loss: 0.2535, Test Loss: 2.1698
# Epoch 140/300, Train Loss: 0.2695, Test Loss: 2.2032
# Epoch 145/300, Train Loss: 0.2310, Test Loss: 2.3280
# Epoch 150/300, Train Loss: 0.1823, Test Loss: 2.5517
# Epoch 155/300, Train Loss: 0.1694, Test Loss: 2.5077
# Epoch 160/300, Train Loss: 0.1499, Test Loss: 2.6860
# Epoch 165/300, Train Loss: 0.1128, Test Loss: 2.7889
# Epoch 170/300, Train Loss: 0.0864, Test Loss: 2.9061
# Epoch 175/300, Train Loss: 0.0632, Test Loss: 3.0482
# Epoch 180/300, Train Loss: 0.2284, Test Loss: 3.0723
# Epoch 185/300, Train Loss: 0.2754, Test Loss: 2.9825
# Epoch 190/300, Train Loss: 0.1470, Test Loss: 2.4382
# Epoch 195/300, Train Loss: 0.0888, Test Loss: 2.5015
# Epoch 200/300, Train Loss: 0.0544, Test Loss: 2.5242
# Epoch 205/300, Train Loss: 0.0510, Test Loss: 2.6637
# Epoch 210/300, Train Loss: 0.0349, Test Loss: 2.8234
# Epoch 215/300, Train Loss: 0.0265, Test Loss: 2.9349
# Epoch 220/300, Train Loss: 0.0205, Test Loss: 3.0424
# Epoch 225/300, Train Loss: 0.0164, Test Loss: 3.1317
# Epoch 230/300, Train Loss: 0.0127, Test Loss: 3.2227
# Epoch 235/300, Train Loss: 0.0132, Test Loss: 3.2048
# Epoch 240/300, Train Loss: 0.0713, Test Loss: 3.1409
# Epoch 245/300, Train Loss: 0.0487, Test Loss: 3.1555
# Epoch 250/300, Train Loss: 0.0321, Test Loss: 3.1295
# Epoch 255/300, Train Loss: 0.0222, Test Loss: 3.0613
# Epoch 260/300, Train Loss: 0.0165, Test Loss: 3.2103
# Epoch 265/300, Train Loss: 0.0126, Test Loss: 3.3380
# Epoch 270/300, Train Loss: 0.0098, Test Loss: 3.4403
# Epoch 275/300, Train Loss: 0.0077, Test Loss: 3.5032
# Epoch 280/300, Train Loss: 0.0061, Test Loss: 3.5259
# Epoch 285/300, Train Loss: 0.0048, Test Loss: 3.5569
# Epoch 290/300, Train Loss: 0.0037, Test Loss: 3.5863
# Epoch 295/300, Train Loss: 0.0030, Test Loss: 3.6096
# Epoch 300/300, Train Loss: 0.0025, Test Loss: 3.6319

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# Get accuracy
with torch.no_grad():
  p_train = model(X_train)
  p_train = (p_train.cpu().numpy() > 0)
  train_acc = np.mean(y_train.cpu().numpy() == p_train)

  p_test = model(X_test)
  p_test = (p_test.cpu().numpy() > 0)
  test_acc = np.mean(y_test.cpu().numpy() == p_test)
print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}")
# Out:
# Train acc: 1.0000, Test acc: 0.5073
