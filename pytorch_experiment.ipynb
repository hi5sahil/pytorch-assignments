# %%
# !conda list -f pytorch
# Out:
# # packages in environment at /Users/Z0094BV/miniconda3:
# #
# # Name                    Version                   Build  Channel

# %%
# !conda uninstall --yes setuptools
# !conda install --yes setuptools
# !conda update --yes setuptools
# Out:
# ...
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - setuptools
#
#
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-64::conda==4.13.0=py39h6e9494a_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/Z0094BV/miniconda3
#
#   added / updated specs:
#     - setuptools
#
#
# The following NEW packages will be INSTALLED:
#
#   setuptools         pkgs/main/osx-64::setuptools-65.6.3-py39hecd8cb5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> pkgs/main::ca-certificates-2023.01.10-hecd8cb5_0
#   certifi            conda-forge::certifi-2022.6.15-py39h6~ --> pkgs/main::certifi-2022.12.7-py39hecd8cb5_0
#   openssl            conda-forge::openssl-1.1.1q-hfe4f2af_0 --> pkgs/main::openssl-1.1.1t-hca72f7f_0
#
#
# ...

# %%
# !conda update --yes --force conda
# !conda update --yes conda
# !conda update --yes anaconda
# Out:
# WARNING: The --force flag will be removed in a future conda release.
#          See 'conda update --help' for details about the --force-reinstall
#          and --clobber flags.
#
#
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-64::conda==4.13.0=py39h6e9494a_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/Z0094BV/miniconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-2.0.2|   py39hecd8cb5_0         268 KB
#     conda-package-streaming-0.7.0|   py39hecd8cb5_0          28 KB
#     cryptography-39.0.1        |   py39hf6deb26_0         1.0 MB
#     idna-3.4                   |   py39hecd8cb5_0          96 KB
# ...

# %%
# !conda create --yes -n pytorch python=3.7
# !conda activate --yes pytorch
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Z0094BV/miniconda3/envs/pytorch
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.01.10 |       hecd8cb5_0         121 KB
#     certifi-2022.12.7          |   py37hecd8cb5_0         151 KB
#     libffi-3.4.2               |       hecd8cb5_6         127 KB
#     ncurses-6.4                |       hcec6c5f_0        1018 KB
#     openssl-1.1.1t             |       hca72f7f_0         3.3 MB
#     pip-22.3.1                 |   py37hecd8cb5_0         2.7 MB
#     python-3.7.16              |       h218abb5_0        23.5 MB
#     readline-8.2               |       hca72f7f_0         328 KB
#     setuptools-65.6.3          |   py37hecd8cb5_0         1.1 MB
#     sqlite-3.41.1              |       h6c40b1e_0         1.2 MB
# ...

# %%
# !conda install --yes pytorch torchvision -c pytorch
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-64::conda==4.13.0=py39h6e9494a_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/Z0094BV/miniconda3
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py39hecd8cb5_0         151 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     freetype-2.12.1            |       hd8bbffd_0         592 KB
#     future-0.18.3              |   py39hecd8cb5_0         677 KB
#     giflib-5.2.1               |       h6c40b1e_3          81 KB
#     jpeg-9e                    |       h6c40b1e_1         252 KB
#     lcms2-2.12                 |       hf1fd2bf_0         284 KB
# ...

# %%
# !conda install --yes pytorch torchvision cudatoolkit=10.1 -c pytorch
