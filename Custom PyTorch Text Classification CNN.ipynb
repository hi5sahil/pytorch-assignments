# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Unfortunately this URL doesn't work directly with pd.read_csv
# !wget -nc https://lazyprogrammer.me/course_files/spam.csv

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# drop unnecessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# rename columns to something better
df.columns = ['labels', 'data']

# %%
df.head()
# Out:
#   labels                                               data
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# create binary labels
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1})

# %%
df_train, df_test = train_test_split(df, test_size=0.33)

# %%
df_train.shape, df_test.shape
# Out:
# ((3733, 3), (1839, 3))

# %%
# 0 = padding
idx = 1
word2idx = {'<PAD>': 0}

# %%
# you could always use gensim or spacy for tokenization,
# but let's keep it simple!
for i, row in df_train.iterrows():
  tokens = row['data'].lower().split() # simple tokenization
  for token in tokens:
    if token not in word2idx:
      word2idx[token] = idx
      idx += 1

# %%
word2idx
# Out:
# {'<PAD>': 0,
#  'prepare': 1,
#  'to': 2,
#  'be': 3,
#  'pleasured': 4,
#  ':)': 5,
#  'ok.': 6,
#  'i.ll': 7,
#  'do': 8,
#  'you': 9,
#  'right': 10,
#  'later.': 11,
#  'honeybee': 12,
#  'said:': 13,
#  "*i'm": 14,
#  'd': 15,
#  'sweetest': 16,
#  'in': 17,
#  'world*': 18,
#  'god': 19,
#  'laughed': 20,
#  '&amp;': 21,
#  '*wait,u': 22,
#  'havnt': 23,
#  'met': 24,
#  'person': 25,
#  'reading': 26,
#  'this': 27,
#  'msg*': 28,
#  'moral:': 29,
#  'even': 30,
#  'can': 31,
#  'crack': 32,
#  'jokes!': 33,
#  'gm+gn+ge+gn:)': 34,
#  'want': 35,
#  '750': 36,
#  'anytime': 37,
#  'any': 38,
#  'network': 39,
#  'mins': 40,
#  '150': 41,
#  'text': 42,
#  'and': 43,
#  'a': 44,
#  'new': 45,
#  'video': 46,
#  'phone': 47,
#  'for': 48,
#  'only': 49,
#  'five': 50,
#  'pounds': 51,
#  'per': 52,
#  'week': 53,
#  'call': 54,
#  '08000776320': 55,
#  'now': 56,
#  'or': 57,
#  'reply': 58,
#  'delivery': 59,
#  'tomorrow': 60,
#  'k...k:)why': 61,
#  'cant': 62,
#  'come': 63,
#  'here': 64,
#  'search': 65,
#  'job:)': 66,
#  'indians': 67,
#  'r': 68,
#  'poor': 69,
#  'but': 70,
#  'india': 71,
#  'is': 72,
#  'not': 73,
#  'country.': 74,
#  'says': 75,
#  'one': 76,
#  'of': 77,
#  'the': 78,
#  'swiss': 79,
#  'bank': 80,
#  'directors.': 81,
#  'he': 82,
#  'that': 83,
#  '\\': 84,
#  '&lt;#&gt;': 85,
#  'lac': 86,
#  'crore\\"': 87,
#  'indian': 88,
#  'money': 89,
#  'deposited': 90,
#  'banks': 91,
#  'which': 92,
#  'used': 93,
#  "'taxless'": 94,
#  'budget': 95,
#  'yrs.': 96,
#  'give': 97,
#  'crore': 98,
#  'jobs': 99,
#  'all': 100,
#  'indians.': 101,
#  'from': 102,
#  'village': 103,
#  'delhi': 104,
#  '4': 105,
#  'lane': 106,
#  'roads.': 107,
#  'forever': 108,
#  'free': 109,
#  'power': 110,
#  'suply': 111,
#  'more': 112,
#  'than': 113,
#  'social': 114,
#  'projects.': 115,
#  'every': 116,
#  'citizen': 117,
#  'get': 118,
#  'monthly': 119,
#  '/-': 120,
#  'no': 121,
#  'need': 122,
#  'world': 123,
#  'imf': 124,
#  'loan.': 125,
#  'think': 126,
#  'how': 127,
#  'our': 128,
#  'blocked': 129,
#  'by': 130,
#  'rich': 131,
#  'politicians.': 132,
#  'we': 133,
#  'have': 134,
#  'full': 135,
#  'rights': 136,
#  'against': 137,
#  'corrupt': 138,
#  'itna': 139,
#  'forward': 140,
#  'karo': 141,
#  'ki': 142,
#  'pura': 143,
#  'padhe.g.m.\\""': 144,
#  'know': 145,
#  'someone': 146,
#  'who': 147,
#  'fancies': 148,
#  'you.': 149,
#  '09058097218': 150,
#  'find': 151,
#  'out': 152,
#  'who.': 153,
#  'pobox': 154,
#  '6,': 155,
#  'ls15hb': 156,
#  '150p': 157,
#  'there': 158,
#  'way': 159,
#  'send': 160,
#  "shade's": 161,
#  'stuff': 162,
#  'her.': 163,
#  'she': 164,
#  'has': 165,
#  'been': 166,
#  'wonderful': 167,
#  'too.': 168,
#  'u': 169,
#  'sure': 170,
#  "they'll": 171,
#  'understand': 172,
#  'that!': 173,
#  'wine': 174,
#  '*': 175,
#  'good': 176,
#  'idea': 177,
#  'just': 178,
#  'had': 179,
#  'slurp!': 180,
#  'no.': 181,
#  'i': 182,
#  'dont': 183,
#  'hear': 184,
#  'anything': 185,
#  'double': 186,
#  '&': 187,
#  '1000': 188,
#  'txts': 189,
#  'on': 190,
#  'orange': 191,
#  'tariffs.': 192,
#  'latest': 193,
#  'motorola,': 194,
#  'sonyericsson': 195,
#  'nokia': 196,
#  'with': 197,
#  'bluetooth': 198,
#  'free!': 199,
#  'mobileupd8': 200,
#  '08000839402': 201,
#  'call2optout/hf8': 202,
#  'k': 203,
#  'pa': 204,
#  'your': 205,
#  'lunch': 206,
#  'aha.': 207,
#  'were': 208,
#  'somewhere': 209,
#  'fredericksburg': 210,
#  'dear': 211,
#  'chechi.': 212,
#  'did': 213,
#  'talk': 214,
#  'her': 215,
#  'problem': 216,
#  'renewal.': 217,
#  'it': 218,
#  'away': 219,
#  'his': 220,
#  'details.': 221,
#  'wanna': 222,
#  'some': 223,
#  'art?!': 224,
#  ':d': 225,
#  'hello': 226,
#  'darling': 227,
#  'are': 228,
#  'today?': 229,
#  'would': 230,
#  'love': 231,
#  'chat,': 232,
#  'why': 233,
#  'tell': 234,
#  'me': 235,
#  'what': 236,
#  'look': 237,
#  'like': 238,
#  'sexy?': 239,
#  'camera': 240,
#  'phones': 241,
#  'linerental': 242,
#  '4.49/month': 243,
#  'cross': 244,
#  'ntwk': 245,
#  'mins.': 246,
#  '1/2': 247,
#  'price': 248,
#  'txt': 249,
#  'bundle': 250,
#  'deals': 251,
#  'also': 252,
#  'avble.': 253,
#  '08001950382': 254,
#  'call2optout/j': 255,
#  'mf': 256,
#  "wasn't": 257,
#  'well': 258,
#  'babe,': 259,
#  'swollen': 260,
#  'glands': 261,
#  'at': 262,
#  'my': 263,
#  'throat': 264,
#  '...': 265,
#  'end': 266,
#  'up': 267,
#  'doing': 268,
#  '?': 269,
#  "i've": 270,
#  'reached': 271,
#  'home': 272,
#  'n': 273,
#  'bathe': 274,
#  'liao...': 275,
#  'now...': 276,
#  'yar': 277,
#  'wanted': 278,
#  '2': 279,
#  'scold': 280,
#  'yest': 281,
#  'late': 282,
#  'already...': 283,
#  'where': 284,
#  'got': 285,
#  'zhong': 286,
#  'se': 287,
#  'qing': 288,
#  'you?': 289,
#  'if': 290,
#  'ask': 291,
#  'b4': 292,
#  'then': 293,
#  "i'll": 294,
#  'go': 295,
#  'w': 296,
#  'lor.': 297,
#  'still': 298,
#  'act': 299,
#  'so': 300,
#  'real.': 301,
#  "i'm": 302,
#  'working': 303,
#  'technical': 304,
#  'support': 305,
#  ':)voice': 306,
#  'process.networking': 307,
#  'field.': 308,
#  'rose': 309,
#  'red,red': 310,
#  'blood,blood': 311,
#  'heart,heart': 312,
#  'u.': 313,
#  'me....': 314,
#  'tis': 315,
#  'ur': 316,
#  'friends..': 317,
#  'including': 318,
#  'me..': 319,
#  'back,': 320,
#  '1-u': 321,
#  'relation!': 322,
#  '2-u': 323,
#  '1': 324,
#  '3-u': 325,
#  'frnd': 326,
#  'many': 327,
#  '4-some1': 328,
#  'luvs': 329,
#  '5+-': 330,
#  'some1': 331,
#  'praying': 332,
#  'marry': 333,
#  'u.:-)': 334,
#  'try': 335,
#  'it....': 336,
#  'drama': 337,
#  'pls.i': 338,
#  'enough': 339,
#  'family': 340,
#  'while': 341,
#  'am': 342,
#  'struggling': 343,
#  'hot': 344,
#  'sun': 345,
#  'strange': 346,
#  'place.no': 347,
#  'reason': 348,
#  'should': 349,
#  'an': 350,
#  'ego': 351,
#  'going': 352,
#  "'if": 353,
#  "invited'": 354,
#  'when': 355,
#  'actually': 356,
#  'its': 357,
#  'necessity': 358,
#  'go.wait': 359,
#  'very': 360,
#  'serious': 361,
#  'reppurcussions.': 362,
#  'haf': 363,
#  'found': 364,
#  'him?': 365,
#  'feel': 366,
#  'stupid': 367,
#  'da': 368,
#  'v': 369,
#  'cam': 370,
#  'was': 371,
#  'working.': 372,
#  'private!': 373,
#  '2003': 374,
#  'account': 375,
#  'statement': 376,
#  'shows': 377,
#  '800': 378,
#  'un-redeemed': 379,
#  's.': 380,
#  'i.': 381,
#  'm.': 382,
#  'points.': 383,
#  '08715203694': 384,
#  'identifier': 385,
#  'code:': 386,
#  '40533': 387,
#  'expires': 388,
#  '31/10/04': 389,
#  'guy': 390,
#  'car': 391,
#  'shop': 392,
#  'flirting': 393,
#  'number': 394,
#  'paperwork': 395,
#  'called': 396,
#  'texted': 397,
#  'me.': 398,
#  'nervous': 399,
#  'because': 400,
#  'course': 401,
#  'may': 402,
#  'address.': 403,
#  'boss': 404,
#  'him,': 405,
#  'knowing': 406,
#  'him': 407,
#  'fired?': 408,
#  'hey': 409,
#  'mate!': 410,
#  'hows': 411,
#  'honey?did': 412,
#  'ave': 413,
#  'holiday?': 414,
#  'gimmi': 415,
#  'de': 416,
#  'goss!x': 417,
#  'drive': 418,
#  'guess': 419,
#  'pub': 420,
#  'im': 421,
#  'in?': 422,
#  'as': 423,
#  'happy': 424,
#  'pig': 425,
#  'clover': 426,
#  'whatever': 427,
#  'saying': 428,
#  'is!': 429,
#  'lor': 430,
#  'toa': 431,
#  'payoh': 432,
#  'place': 433,
#  'walk': 434,
#  'meh...': 435,
#  'k,': 436,
#  'bored': 437,
#  'home..': 438,
#  'ya,': 439,
#  'referin': 440,
#  "mei's": 441,
#  'ex': 442,
#  'wat...': 443,
#  'ah,': 444,
#  'waitin': 445,
#  'treat,': 446,
#  'somebody': 447,
#  'shld': 448,
#  'b': 449,
#  'liao...so': 450,
#  'gd,': 451,
#  'den': 452,
#  'dun': 453,
#  'work': 454,
#  'frm': 455,
#  'tmr': 456,
#  'onwards...': 457,
#  'sch': 458,
#  'fr': 459,
#  '4-6...': 460,
#  'book': 461,
#  'sch...': 462,
#  "it's": 463,
#  'home...': 464,
#  'ya!': 465,
#  'ì_': 466,
#  'taking': 467,
#  'ure': 468,
#  'practical': 469,
#  'lessons?': 470,
#  'start': 471,
#  'june..': 472,
#  'half': 473,
#  'line': 474,
#  'rental': 475,
#  '12': 476,
#  'mths': 477,
#  '500': 478,
#  '100': 479,
#  'txts.': 480,
#  'call2optout/674&': 481,
#  'yo!': 482,
#  'howz': 483,
#  'u?': 484,
#  'girls': 485,
#  'never': 486,
#  'rang': 487,
#  'after': 488,
#  'india.': 489,
#  'l': 490,
#  'strange.': 491,
#  'watching': 492,
#  '2nd': 493,
#  'bed.': 494,
#  'sweet': 495,
#  'dreams,': 496,
#  'miss': 497,
#  'old': 498,
#  'orchard': 499,
#  'near': 500,
#  'univ.': 501,
#  'about': 502,
#  'though.': 503,
#  "can't": 504,
#  'space': 505,
#  'need.': 506,
#  'really': 507,
#  'starting': 508,
#  'become': 509,
#  'issue.': 510,
#  'suggest': 511,
#  'setting': 512,
#  'definite': 513,
#  'move': 514,
#  'out--if': 515,
#  'there--': 516,
#  'greece.': 517,
#  'maybe': 518,
#  'ready': 519,
#  'now.': 520,
#  "that's": 521,
#  'significant': 522,
#  'worry.': 523,
#  'rightio.': 524,
#  '11.48': 525,
#  'then.': 526,
#  'arent': 527,
#  'bright': 528,
#  'early': 529,
#  'morning.': 530,
#  'ok': 531,
#  'hi': 532,
#  'sexy': 533,
#  'buns': 534,
#  '!': 535,
#  'told': 536,
#  'adore': 537,
#  'you,': 538,
#  'loverboy.': 539,
#  'hope': 540,
#  'remember': 541,
#  'thank': 542,
#  'sister': 543,
#  'law': 544,
#  'those': 545,
#  'meatballs': 546,
#  '*grins*': 547,
#  'babe': 548,
#  'great': 549,
#  'day.': 550,
#  'yourself': 551,
#  'beautiful': 552,
#  'one.': 553,
#  'awesome,': 554,
#  "you're": 555,
#  'restocked': 556,
#  'k.': 557,
#  'will': 558,
#  'sent': 559,
#  'again': 560,
#  'morning': 561,
#  'dear...........': 562,
#  'successful': 563,
#  "we've": 564,
#  'spoken': 565,
#  'year?': 566,
#  'anyways': 567,
#  'best': 568,
#  'exam': 569,
#  's.i.m.': 570,
#  '08715203685': 571,
#  'code:4xx26': 572,
#  '13/10/04': 573,
#  'freemsg:': 574,
#  '1-month': 575,
#  'unlimited': 576,
#  'calls!': 577,
#  'activate': 578,
#  'smartcall': 579,
#  'txt:': 580,
#  'no:': 581,
#  '68866.': 582,
#  'subscriptn3gbp/wk': 583,
#  'calls': 584,
#  'help:': 585,
#  '08448714184': 586,
#  'stop?txt': 587,
#  'stop': 588,
#  'landlineonly': 589,
#  'won': 590,
#  'guaranteed': 591,
#  'å£1000': 592,
#  'cash': 593,
#  'å£2000': 594,
#  'prize.': 595,
#  'claim': 596,
#  'yr': 597,
#  'prize': 598,
#  'customer': 599,
#  'service': 600,
#  'representative': 601,
#  '08714712394': 602,
#  'between': 603,
#  '10am-7pm': 604,
#  'heard': 605,
#  'u4': 606,
#  'while.': 607,
#  'rude': 608,
#  'chat': 609,
#  'private': 610,
#  '01223585334': 611,
#  'cum.': 612,
#  'wan': 613,
#  '2c': 614,
#  'pics': 615,
#  'gettin': 616,
#  'shagged': 617,
#  'pix': 618,
#  '8552.': 619,
#  '2end': 620,
#  '8552': 621,
#  'sam': 622,
#  'xxx': 623,
#  'realy': 624,
#  'sorry-i': 625,
#  "don't": 626,
#  'recognise': 627,
#  'confused': 628,
#  'please?!': 629,
#  'eyes': 630,
#  'philosophy': 631,
#  'days': 632,
#  'billion': 633,
#  'classes,': 634,
#  'right?': 635,
#  'oi.': 636,
#  'ami': 637,
#  'parchi': 638,
#  'na': 639,
#  're.': 640,
#  'kicchu': 641,
#  'kaaj': 642,
#  'korte': 643,
#  'iccha': 644,
#  'korche': 645,
#  'na.': 646,
#  'ta': 647,
#  'tul': 648,
#  'plz.': 649,
#  'hiya': 650,
#  ',': 651,
#  'paying': 652,
#  'into': 653,
#  'account?': 654,
#  'so,': 655,
#  'thanks.': 656,
#  'pleasant': 657,
#  'surprise': 658,
#  'checked': 659,
#  'balance': 660,
#  '-u': 661,
#  'c,': 662,
#  'statements': 663,
#  'acc': 664,
#  'subscribed': 665,
#  'mobile': 666,
#  'content': 667,
#  'uk': 668,
#  'å£3': 669,
#  '10': 670,
#  'until': 671,
#  '82324.': 672,
#  'helpline': 673,
#  '08706091795': 674,
#  'otherwise': 675,
#  'part': 676,
#  'time': 677,
#  'job': 678,
#  'na-tuition..': 679,
#  'lunch.': 680,
#  'oops': 681,
#  'sorry.': 682,
#  'check': 683,
#  'mind': 684,
#  'picking': 685,
#  'tomo': 686,
#  'eight': 687,
#  'station.': 688,
#  'ok?': 689,
#  'doubt': 690,
#  'could': 691,
#  'handle': 692,
#  '5': 693,
#  'times': 694,
#  'night': 695,
#  'case...': 696,
#  'scores': 697,
#  'sophas': 698,
#  'secondary': 699,
#  'application': 700,
#  'few': 701,
#  'schools.': 702,
#  'thinking': 703,
#  'applying,': 704,
#  'research': 705,
#  'cost': 706,
#  'also.': 707,
#  'contact': 708,
#  'joke': 709,
#  'ogunrinde,': 710,
#  'school': 711,
#  'less': 712,
#  'expensive': 713,
#  'ones': 714,
#  'lol': 715,
#  'without': 716,
#  'big': 717,
#  'sale': 718,
#  'together.': 719,
#  'secret': 720,
#  'admirer': 721,
#  'looking': 722,
#  'make': 723,
#  'u-find': 724,
#  'they': 725,
#  'r*reveal': 726,
#  'thinks': 727,
#  'special-call': 728,
#  '09058094599': 729,
#  'do,': 730,
#  'dog': 731,
#  'must': 732,
#  'always': 733,
#  'wait': 734,
#  'till': 735,
#  'day': 736,
#  'word': 737,
#  'run': 738,
#  'cell': 739,
#  'already?': 740,
#  'dunno': 741,
#  'lei...': 742,
#  'might': 743,
#  'eatin': 744,
#  'wif': 745,
#  'frens...': 746,
#  'eat': 747,
#  'lar': 748,
#  'weekend': 749,
#  'fine': 750,
#  '(an': 751,
#  'excuse': 752,
#  'too': 753,
#  'much': 754,
#  'decorating)': 755,
#  'being': 756,
#  'man.': 757,
#  'build': 758,
#  'snowman': 759,
#  'snow': 760,
#  'angels': 761,
#  'snowball': 762,
#  'fights.': 763,
#  'haha...': 764,
#  'yup': 765,
#  'hopefully': 766,
#  'lose': 767,
#  'kg': 768,
#  'mon.': 769,
#  'hip': 770,
#  'hop': 771,
#  'weigh': 772,
#  'finally': 773,
#  'match': 774,
#  'heading': 775,
#  'towards': 776,
#  'draw': 777,
#  'prediction.': 778,
#  'awarded': 779,
#  'city': 780,
#  'break': 781,
#  'win': 782,
#  'å£200': 783,
#  'summer': 784,
#  'shopping': 785,
#  'spree': 786,
#  'wk.': 787,
#  'store': 788,
#  '88039.skilgme.tscs087147403231winawk!age16+å£1.50perwksub': 789,
#  'denying': 790,
#  'words': 791,
#  'please': 792,
#  'sorry,': 793,
#  'later': 794,
#  'yes': 795,
#  'princess!': 796,
#  'night.': 797,
#  'wish': 798,
#  'command...': 799,
#  'office': 800,
#  'da..': 801,
#  'responding': 802,
#  'anything.': 803,
#  'room': 804,
#  'went': 805,
#  'diwali': 806,
#  'coming.': 807,
#  'makes': 808,
#  'died.': 809,
#  'y': 810,
#  'there?': 811,
#  'c': 812,
#  'doctor?': 813,
#  'noe': 814,
#  'files': 815,
#  'computers?': 816,
#  'supports': 817,
#  'ass': 818,
#  'srt': 819,
#  'thnk.': 820,
#  'ps3': 821,
#  'play': 822,
#  'through': 823,
#  'usb': 824,
#  'nothing': 825,
#  'spl..wat': 826,
#  'abt': 827,
#  'whr': 828,
#  'ru?': 829,
#  'da:)how': 830,
#  'todays': 831,
#  'class?': 832,
#  'willing': 833,
#  'pay?': 834,
#  'boys': 835,
#  'made': 836,
#  'fun': 837,
#  'today.': 838,
#  'problem.': 839,
#  'message': 840,
#  'durban': 841,
#  '4mths': 842,
#  'free.': 843,
#  '11mths+?': 844,
#  'mobilesdirect': 845,
#  '08000938767': 846,
#  'update': 847,
#  'now!': 848,
#  'or2stoptxt': 849,
#  't&cs': 850,
#  'sorry': 851,
#  'man': 852,
#  "account's": 853,
#  'dry': 854,
#  'would,': 855,
#  'trade': 856,
#  'back': 857,
#  'buy': 858,
#  'shit': 859,
#  'credit': 860,
#  'card': 861,
#  'sindu': 862,
#  'birla': 863,
#  'soft': 864,
#  '..': 865,
#  'chennai': 866,
#  'velachery:)': 867,
#  'whats': 868,
#  'up?': 869,
#  'sleeping': 870,
#  'morning?': 871,
#  'holding': 872,
#  'tightly.': 873,
#  'making': 874,
#  'see': 875,
#  'important': 876,
#  'are.': 877,
#  'mean': 878,
#  'life': 879,
#  'umma': 880,
#  'vava': 881,
#  'lot': 882,
#  'sorry!': 883,
#  'unsubscribe': 884,
#  'yet.': 885,
#  'mob': 886,
#  'offer': 887,
#  'package': 888,
#  'min': 889,
#  'term': 890,
#  '54': 891,
#  'weeks>': 892,
#  'pls': 893,
#  'resubmit': 894,
#  'request': 895,
#  'expiry.': 896,
#  'themob': 897,
#  'help': 898,
#  'info': 899,
#  'happy...': 900,
#  'jus': 901,
#  'true': 902,
#  'missin': 903,
#  'cos': 904,
#  'him!': 905,
#  "haven't": 906,
#  'done': 907,
#  'guilty': 908,
#  'about,': 909,
#  'kallis': 910,
#  'wont': 911,
#  'bat': 912,
#  'innings.': 913,
#  'ringtone': 914,
#  'waiting': 915,
#  'collected.': 916,
#  'simply': 917,
#  'password': 918,
#  '\\mix\\"': 919,
#  '85069': 920,
#  'verify.': 921,
#  'usher': 922,
#  'britney.': 923,
#  'fml': 924,
#  'congrats!': 925,
#  'year': 926,
#  'special': 927,
#  'cinema': 928,
#  'pass': 929,
#  'yours.': 930,
#  '09061209465': 931,
#  'suprman': 932,
#  'v,': 933,
#  'matrix3,': 934,
#  'starwars3,': 935,
#  'etc': 936,
#  'bx420-ip4-5we.': 937,
#  '150pm.': 938,
#  'out!': 939,
#  'yes,': 940,
#  'small': 941,
#  'kid..': 942,
#  'boost': 943,
#  'energy..': 944,
#  'ìï': 945,
#  'write': 946,
#  'wat..': 947,
#  'happened..!': 948,
#  'aftr': 949,
#  'decades..!': 950,
#  'beer': 951,
#  'cheaper': 952,
#  'petrol!': 953,
#  'goverment': 954,
#  'expects': 955,
#  'us': 956,
#  '\\drink\\".': 957,
#  '.': 958,
#  '\\"drive': 959,
#  '\\""': 960,
#  'receipt': 961,
#  'sound...': 962,
#  'gd': 963,
#  'luck!': 964,
#  'dude,': 965,
#  'friends': 966,
#  'afraid': 967,
#  ':(': 968,
#  'msg': 969,
#  'leave': 970,
#  'house.': 971,
#  'kaiez...': 972,
#  'enjoy': 973,
#  'tuition...': 974,
#  'gee...': 975,
#  'thk': 976,
#  'e': 977,
#  'second': 978,
#  'option': 979,
#  'sounds': 980,
#  'beta...': 981,
#  'yan': 982,
#  'jiu': 983,
#  'u...': 984,
#  'ugh': 985,
#  'long': 986,
#  'exhausted.': 987,
#  'cuddle': 988,
#  'take': 989,
#  'nap': 990,
#  'later,': 991,
#  'network.': 992,
#  'urgnt,': 993,
#  'sms': 994,
#  'thnk': 995,
#  'wrong': 996,
#  'calling': 997,
#  'roommates': 998,
#  'took': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 10569

# %%
# convert data into word indices
# note: could have done this on the fly earlier
train_sentences_as_int = []
for i, row in df_train.iterrows():
  tokens = row['data'].lower().split()
  sentence_as_int = [word2idx[token] for token in tokens]
  train_sentences_as_int.append(sentence_as_int)

# %%
test_sentences_as_int = []
for i, row in df_test.iterrows():
  tokens = row['data'].lower().split()
  sentence_as_int = [word2idx[token] for token in tokens if token in word2idx]
  test_sentences_as_int.append(sentence_as_int)

# %%
len(train_sentences_as_int), len(test_sentences_as_int)
# Out:
# (3733, 1839)

# %%
def data_generator(X, y, batch_size=32):
  X, y = shuffle(X, y)
  n_batches = int(np.ceil(len(y) / batch_size))
  for i in range(n_batches):
    end = min((i + 1) * batch_size, len(y))

    X_batch = X[i * batch_size:end]
    y_batch = y[i * batch_size:end]

    # pad X_batch to be N x T
    max_len = np.max([len(x) for x in X_batch])
    for j in range(len(X_batch)):
      x = X_batch[j]
      pad = [0] * (max_len - len(x))
      X_batch[j] = pad + x
    
    # convert to tensor
    X_batch = torch.from_numpy(np.array(X_batch)).long()
    y_batch = torch.from_numpy(np.array(y_batch)).long()
    
    yield X_batch, y_batch

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# What is the shape of embedding output?
# N x T x D
embed = nn.Embedding(len(word2idx), 20)
for inputs, targets in data_generator(train_sentences_as_int, df_train.b_labels):
  out = embed(inputs)
  print("Input shape:", inputs.shape) # N x T
  print("Output shape:", out.shape)   # N x T x D
  break
# Out:
# Input shape: torch.Size([32, 41])
# Output shape: torch.Size([32, 41, 20])

# %%
# Define the model
class CNN(nn.Module):
  def __init__(self, n_vocab, embed_dim, n_outputs):
    super(CNN, self).__init__()
    self.V = n_vocab
    self.D = embed_dim
    self.K = n_outputs

    # if input is T words
    # then output is (T, D) matrix
    self.embed = nn.Embedding(self.V, self.D)        

    # conv 1D layers & pool 1D layers
    self.conv1 = nn.Conv1d(self.D, 32, 3, padding=1) 
    self.pool1 = nn.MaxPool1d(2)                     
    self.conv2 = nn.Conv1d(32, 64, 3, padding=1)     
    self.pool2 = nn.MaxPool1d(2)                     
    self.conv3 = nn.Conv1d(64, 128, 3, padding=1)    
    
    self.fc = nn.Linear(128, self.K)                 
  
  def forward(self, X):                        # input is (N, T)
    # embedding layer
    # turns word indexes into word vectors
    out = self.embed(X)                        # output is (N, T, D)

    # note: output of embedding is always
    # (N, T, D)
    # conv1d expects
    # (N, D, T)

    # conv layers
    out = out.permute(0, 2, 1)                 # output is (N, D, T)
    out = self.conv1(out)                      # output is (N, M, T)
    out = F.relu(out)
    out = self.pool1(out)                      # output is (N, M, T2)
    out = self.conv2(out)                      # output is (N, M2, T2)
    out = F.relu(out)
    out = self.pool2(out)                      # output is (N, M2, T3)
    out = self.conv3(out)                      # output is (N, M3, T3)
    out = F.relu(out)

    # change it back
    out = out.permute(0, 2, 1)                 # output is (N, T3, M3)

    # max pool
    out, _ = torch.max(out, 1)                 # output is (N, M3)

    # final dense layer
    out = self.fc(out)                         # output is (N, K)
    return out

# %%
model = CNN(len(word2idx), 20, 1)
model.to(device)
# Out:
# CNN(
#   (embed): Embedding(10569, 20)
#   (conv1): Conv1d(20, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_gen = lambda: data_generator(train_sentences_as_int, df_train.b_labels)
test_gen = lambda: data_generator(test_sentences_as_int, df_test.b_labels)

# %%
# A function to encapsulate the training loop
def batch_gd(model, criterion, optimizer, epochs):
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    t0 = datetime.now()
    train_loss = []
    for inputs, targets in train_gen():
      # print("inputs.shape:", inputs.shape, "targets.shape:", targets.shape)
      targets = targets.view(-1, 1).float()
      # move data to GPU
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      # print("outputs.shape:", outputs.shape)
      loss = criterion(outputs, targets)
        
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    test_loss = []
    for inputs, targets in test_gen():
      inputs, targets = inputs.to(device), targets.to(device)
      targets = targets.view(-1, 1).float()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      test_loss.append(loss.item())
    test_loss = np.mean(test_loss)

    # Save losses
    train_losses[it] = train_loss
    test_losses[it] = test_loss
    
    dt = datetime.now() - t0
    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, \
      Test Loss: {test_loss:.4f}, Duration: {dt}')
  
  return train_losses, test_losses

# %%
train_losses, test_losses = batch_gd(
    model, criterion, optimizer, 8)
# Out:
# Epoch 1/8, Train Loss: 0.4064,       Test Loss: 0.3600, Duration: 0:00:01.009042
# Epoch 2/8, Train Loss: 0.2909,       Test Loss: 0.2498, Duration: 0:00:01.220799
# Epoch 3/8, Train Loss: 0.1774,       Test Loss: 0.1638, Duration: 0:00:00.913854
# Epoch 4/8, Train Loss: 0.1044,       Test Loss: 0.1450, Duration: 0:00:00.892588
# Epoch 5/8, Train Loss: 0.0737,       Test Loss: 0.1668, Duration: 0:00:00.847106
# Epoch 6/8, Train Loss: 0.0502,       Test Loss: 0.1351, Duration: 0:00:00.906038
# Epoch 7/8, Train Loss: 0.0417,       Test Loss: 0.1417, Duration: 0:00:00.933015
# Epoch 8/8, Train Loss: 0.0264,       Test Loss: 0.1959, Duration: 0:00:00.930228

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# Accuracy

n_correct = 0.
n_total = 0.
for inputs, targets in train_gen():
  targets = targets.view(-1, 1).float()
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward pass
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)
  
  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

train_acc = n_correct / n_total


n_correct = 0.
n_total = 0.
for inputs, targets in test_gen():
  targets = targets.view(-1, 1).float()
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward pass
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)
  
  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

test_acc = n_correct / n_total
print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}")
# Out:
# Train acc: 0.9906, Test acc: 0.9554
